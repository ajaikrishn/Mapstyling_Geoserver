# %%
import os
import shapely
import fiona
import geopandas as gpd
import pandas as pd
import matplotlib as plt
from pysld.style import StyleSld
from geo.Geoserver import Geoserver

# %%
data_dir='/home/ajai-krishna/work/qgis_geoserver/India states data'
files_path=[os.path.join(data_dir,i) for i in os.listdir(data_dir)]
save_dir=os.path.join('/home/ajai-krishna/work/qgis_geoserver/Styles')
style_dir='/home/ajai-krishna/work/qgis_geoserver/Styles/'
style_files = [os.path.join(style_dir,i) for i in os.listdir(style_dir)]

# %%
files_path
# Out:
# ['/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_simple-daily-indices_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm-ond_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tw-year-max_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_max-5day-precip_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-CDD_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-CSD_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-rh_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_max-5day-precip_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_hwdi_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-max-1day-precip_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm-year_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_CDD_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_CSD_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-tw_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-Heavy-rainfall-days-10mm_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_simple-daily-indices_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-Heavy-rainfall-days-10mm_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tas-celsius_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_hwdi_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_rainyday-frequency_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tw_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tw-MAM-max_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_hurs_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-max-5day-precip_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm-year_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-CSD_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-CDD_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_CDD_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_DJF-Tmin_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-Heavy-rainfall-days-10mm_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-Heavy-rainfall-days-20mm_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_max-1day-precip_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-max-5day-precip_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_rainyday-frequency_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tasmax-celsius_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tw_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-SDII_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-CDD_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-SDII_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_hurs_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-max-5day-precip_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-SDII_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-Heavy-rainfall-days-20mm_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm-ond_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-max-1day-precip_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tasmax-celsius_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-Heavy-rainfall-days-20mm_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tasmin-celsius_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tw-year-max_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_warm-spell-duration-index_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-SDII_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tw-MAM-max_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-tw_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_max-1day-precip_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_CSD_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-CDD_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_warm-spell-duration-index_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-Heavy-rainfall-days-10mm_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-max-1day-precip_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm-jjas_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-max-1day-precip_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tasmin-celsius_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_tas-celsius_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_OND-Heavy-rainfall-days-20mm_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_DJF-Tmin_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_JJAS-max-5day-precip_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_pr-mm-jjas_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-tmax_ssp585_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-tmax_ssp245_2021-2040.gpkg',
#  '/home/ajai-krishna/work/qgis_geoserver/India states data/India_states_MAM-rh_ssp245_2021-2040.gpkg']

# %%
len(files_path)
# Out:
# 72

# %% [markdown]
# gdfs = [gpd.read_file(file_path) for file_path in files_path]
# data = pd.concat(gdfs, ignore_index=True)

# %%
server = Geoserver('http://localhost:8080/geoserver', username='admin', password='geoserver')

# %% [raw]
# sld = StyleSld(
#         style_name='polygonStyle',
#         geom_type='polygon',
#         attribute_name='mean',
#         values=gdf['mean'].unique().tolist(),
#         number_of_class=5,
#         classification_method='natural_break',
#         color_palette=palette
#     )
#
# style = sld.generate_classified_style()
# style=server.upload_style(path = sld_path, name = file_name, workspace = 'Climate_data_Indian_states')
# server.publish_style(layer_name = datastore_name, style_name = file_name, workspace = 'Climate_data_Indian_states')

# %%
stores={}
styles={}

for i in files_path:
    pr_indices = ['jjas','ond','pr-mm','rainyday-frequency','simple-daily-indices']
    file_name = '_'.join(i.split('_')[-3:-1])
    
    datastore_name = os.path.splitext(os.path.basename(i))[0]
    try:
        server.delete_featurestore(featurestore_name = datastore_name, workspace = 'Climate_data_Indian_states')
        print(f'deleted {datastore_name}')
    except:
        print(f"good")
    store = server.create_gpkg_datastore(path = i)
    stores[datastore_name] = store
    print(f"created data_store:{datastore_name}")

    gdf = gpd.read_file(i)
    layers = fiona.listlayers(i)
    layer_name = layers[0] if layers else datastore_name
    
    # Decide palette
    if any(file_name.lower().startswith(idx) for idx in pr_indices):
        palette = 'Greens'
    else:
        palette = 'Reds'

    sld = StyleSld(
        style_name='polygonStyle',
        geom_type='polygon',
        attribute_name='mean',
        values=gdf['mean'].tolist(),
        number_of_class= 5,
        classification_method='natural_break',
        color_palette=palette
    )

    style = sld.generate_classified_style()
    

    sld_path = os.path.join(save_dir, f"simple_style_{file_name}.sld")
    with open(sld_path, 'w') as f:
        f.write(style)
    print(f"✅ Created SLD for {file_name} → {palette}")
    
    try:
        server.delete_style(style_name = file_name, workspace='Climate_data_Indian_states')
        print(f'deleted {file_name}')
    except Exception:
        print(f'style {file_name} not found, skipping delete')   
    
    style1 = server.upload_style(path = sld_path, name = file_name, workspace = 'Climate_data_Indian_states')
    styles[file_name] = style1
    print(f'style uploaded {file_name}')
    
    # layer_name = datastore_name
    server.publish_style(layer_name= layer_name, style_name = file_name ,workspace = 'Climate_data_Indian_states',)
    print(f'published {layer_name} to {datastore_name}')
# Out:
# deleted India_states_simple-daily-indices_ssp245_2021-2040
# created data_store:India_states_simple-daily-indices_ssp245_2021-2040
# ✅ Created SLD for simple-daily-indices_ssp245 → Greens
# style simple-daily-indices_ssp245 not found, skipping delete
# style uploaded simple-daily-indices_ssp245
# published simple-daily-indices_ssp245_2021-2040 to India_states_simple-daily-indices_ssp245_2021-2040
# deleted India_states_pr-mm-ond_ssp585_2021-2040
# created data_store:India_states_pr-mm-ond_ssp585_2021-2040
# ✅ Created SLD for pr-mm-ond_ssp585 → Greens
# style pr-mm-ond_ssp585 not found, skipping delete
# style uploaded pr-mm-ond_ssp585
# published pr-mm-ond_ssp585_2021-2040 to India_states_pr-mm-ond_ssp585_2021-2040
# deleted India_states_tw-year-max_ssp585_2021-2040
# created data_store:India_states_tw-year-max_ssp585_2021-2040
# ✅ Created SLD for tw-year-max_ssp585 → Reds
# deleted tw-year-max_ssp585
# style uploaded tw-year-max_ssp585
# published tw-year-max_ssp585_2021-2040 to India_states_tw-year-max_ssp585_2021-2040
# deleted India_states_max-5day-precip_ssp585_2021-2040
# created data_store:India_states_max-5day-precip_ssp585_2021-2040
# ✅ Created SLD for max-5day-precip_ssp585 → Reds
# style max-5day-precip_ssp585 not found, skipping delete
# style uploaded max-5day-precip_ssp585
# published max-5day-precip_ssp585_2021-2040 to India_states_max-5day-precip_ssp585_2021-2040
# deleted India_states_OND-CDD_ssp245_2021-2040
# created data_store:India_states_OND-CDD_ssp245_2021-2040
# ✅ Created SLD for OND-CDD_ssp245 → Greens
# style OND-CDD_ssp245 not found, skipping delete
# style uploaded OND-CDD_ssp245
# published OND-CDD_ssp245_2021-2040 to India_states_OND-CDD_ssp245_2021-2040
# deleted India_states_MAM-CSD_ssp585_2021-2040
# created data_store:India_states_MAM-CSD_ssp585_2021-2040
# ✅ Created SLD for MAM-CSD_ssp585 → Reds
# style MAM-CSD_ssp585 not found, skipping delete
# style uploaded MAM-CSD_ssp585
# published MAM-CSD_ssp585_2021-2040 to India_states_MAM-CSD_ssp585_2021-2040
# deleted India_states_MAM-rh_ssp585_2021-2040
# created data_store:India_states_MAM-rh_ssp585_2021-2040
# ✅ Created SLD for MAM-rh_ssp585 → Reds
# style MAM-rh_ssp585 not found, skipping delete
# style uploaded MAM-rh_ssp585
# published MAM-rh_ssp585_2021-2040 to India_states_MAM-rh_ssp585_2021-2040
# deleted India_states_max-5day-precip_ssp245_2021-2040
# created data_store:India_states_max-5day-precip_ssp245_2021-2040
# ✅ Created SLD for max-5day-precip_ssp245 → Reds
# style max-5day-precip_ssp245 not found, skipping delete
# style uploaded max-5day-precip_ssp245
# published max-5day-precip_ssp245_2021-2040 to India_states_max-5day-precip_ssp245_2021-2040
# deleted India_states_hwdi_ssp245_2021-2040
# created data_store:India_states_hwdi_ssp245_2021-2040
# ✅ Created SLD for hwdi_ssp245 → Reds
# style hwdi_ssp245 not found, skipping delete
# style uploaded hwdi_ssp245
# published hwdi_ssp245_2021-2040 to India_states_hwdi_ssp245_2021-2040
# deleted India_states_OND-max-1day-precip_ssp585_2021-2040
# created data_store:India_states_OND-max-1day-precip_ssp585_2021-2040
# ✅ Created SLD for OND-max-1day-precip_ssp585 → Greens
# style OND-max-1day-precip_ssp585 not found, skipping delete
# style uploaded OND-max-1day-precip_ssp585
# published OND-max-1day-precip_ssp585_2021-2040 to India_states_OND-max-1day-precip_ssp585_2021-2040
# deleted India_states_pr-mm-year_ssp585_2021-2040
# created data_store:India_states_pr-mm-year_ssp585_2021-2040
# ✅ Created SLD for pr-mm-year_ssp585 → Greens
# style pr-mm-year_ssp585 not found, skipping delete
# style uploaded pr-mm-year_ssp585
# published pr-mm-year_ssp585_2021-2040 to India_states_pr-mm-year_ssp585_2021-2040
# deleted India_states_CDD_ssp585_2021-2040
# created data_store:India_states_CDD_ssp585_2021-2040
# ✅ Created SLD for CDD_ssp585 → Reds
# style CDD_ssp585 not found, skipping delete
# style uploaded CDD_ssp585
# published CDD_ssp585_2021-2040 to India_states_CDD_ssp585_2021-2040
# deleted India_states_CSD_ssp245_2021-2040
# created data_store:India_states_CSD_ssp245_2021-2040
# ✅ Created SLD for CSD_ssp245 → Reds
# style CSD_ssp245 not found, skipping delete
# style uploaded CSD_ssp245
# published CSD_ssp245_2021-2040 to India_states_CSD_ssp245_2021-2040
# deleted India_states_MAM-tw_ssp585_2021-2040
# created data_store:India_states_MAM-tw_ssp585_2021-2040
# ✅ Created SLD for MAM-tw_ssp585 → Reds
# style MAM-tw_ssp585 not found, skipping delete
# style uploaded MAM-tw_ssp585
# published MAM-tw_ssp585_2021-2040 to India_states_MAM-tw_ssp585_2021-2040
# deleted India_states_OND-Heavy-rainfall-days-10mm_ssp245_2021-2040
# created data_store:India_states_OND-Heavy-rainfall-days-10mm_ssp245_2021-2040
# ✅ Created SLD for OND-Heavy-rainfall-days-10mm_ssp245 → Greens
# style OND-Heavy-rainfall-days-10mm_ssp245 not found, skipping delete
# style uploaded OND-Heavy-rainfall-days-10mm_ssp245
# published OND-Heavy-rainfall-days-10mm_ssp245_2021-2040 to India_states_OND-Heavy-rainfall-days-10mm_ssp245_2021-2040
# deleted India_states_simple-daily-indices_ssp585_2021-2040
# created data_store:India_states_simple-daily-indices_ssp585_2021-2040
# ✅ Created SLD for simple-daily-indices_ssp585 → Greens
# style simple-daily-indices_ssp585 not found, skipping delete
# style uploaded simple-daily-indices_ssp585
# published simple-daily-indices_ssp585_2021-2040 to India_states_simple-daily-indices_ssp585_2021-2040
# deleted India_states_JJAS-Heavy-rainfall-days-10mm_ssp245_2021-2040
# created data_store:India_states_JJAS-Heavy-rainfall-days-10mm_ssp245_2021-2040
# ✅ Created SLD for JJAS-Heavy-rainfall-days-10mm_ssp245 → Greens
# style JJAS-Heavy-rainfall-days-10mm_ssp245 not found, skipping delete
# style uploaded JJAS-Heavy-rainfall-days-10mm_ssp245
# published JJAS-Heavy-rainfall-days-10mm_ssp245_2021-2040 to India_states_JJAS-Heavy-rainfall-days-10mm_ssp245_2021-2040
# deleted India_states_tas-celsius_ssp245_2021-2040
# created data_store:India_states_tas-celsius_ssp245_2021-2040
# ✅ Created SLD for tas-celsius_ssp245 → Reds
# style tas-celsius_ssp245 not found, skipping delete
# style uploaded tas-celsius_ssp245
# published tas-celsius_ssp245_2021-2040 to India_states_tas-celsius_ssp245_2021-2040
# deleted India_states_hwdi_ssp585_2021-2040
# created data_store:India_states_hwdi_ssp585_2021-2040
# ✅ Created SLD for hwdi_ssp585 → Reds
# style hwdi_ssp585 not found, skipping delete
# style uploaded hwdi_ssp585
# published hwdi_ssp585_2021-2040 to India_states_hwdi_ssp585_2021-2040
# deleted India_states_rainyday-frequency_ssp245_2021-2040
# created data_store:India_states_rainyday-frequency_ssp245_2021-2040
# ✅ Created SLD for rainyday-frequency_ssp245 → Greens
# style rainyday-frequency_ssp245 not found, skipping delete
# style uploaded rainyday-frequency_ssp245
# published rainyday-frequency_ssp245_2021-2040 to India_states_rainyday-frequency_ssp245_2021-2040
# deleted India_states_tw_ssp245_2021-2040
# created data_store:India_states_tw_ssp245_2021-2040
# ✅ Created SLD for tw_ssp245 → Reds
# deleted tw_ssp245
# style uploaded tw_ssp245
# published tw_ssp245_2021-2040 to India_states_tw_ssp245_2021-2040
# deleted India_states_tw-MAM-max_ssp245_2021-2040
# created data_store:India_states_tw-MAM-max_ssp245_2021-2040
# ✅ Created SLD for tw-MAM-max_ssp245 → Reds
# style tw-MAM-max_ssp245 not found, skipping delete
# style uploaded tw-MAM-max_ssp245
# published tw-MAM-max_ssp245_2021-2040 to India_states_tw-MAM-max_ssp245_2021-2040
# deleted India_states_hurs_ssp585_2021-2040
# created data_store:India_states_hurs_ssp585_2021-2040
# ✅ Created SLD for hurs_ssp585 → Reds
# style hurs_ssp585 not found, skipping delete
# style uploaded hurs_ssp585
# published hurs_ssp585_2021-2040 to India_states_hurs_ssp585_2021-2040
# deleted India_states_OND-max-5day-precip_ssp585_2021-2040
# created data_store:India_states_OND-max-5day-precip_ssp585_2021-2040
# ✅ Created SLD for OND-max-5day-precip_ssp585 → Greens
# style OND-max-5day-precip_ssp585 not found, skipping delete
# style uploaded OND-max-5day-precip_ssp585
# published OND-max-5day-precip_ssp585_2021-2040 to India_states_OND-max-5day-precip_ssp585_2021-2040
# deleted India_states_pr-mm-year_ssp245_2021-2040
# created data_store:India_states_pr-mm-year_ssp245_2021-2040
# ✅ Created SLD for pr-mm-year_ssp245 → Greens
# style pr-mm-year_ssp245 not found, skipping delete
# style uploaded pr-mm-year_ssp245
# published pr-mm-year_ssp245_2021-2040 to India_states_pr-mm-year_ssp245_2021-2040
# deleted India_states_MAM-CSD_ssp245_2021-2040
# created data_store:India_states_MAM-CSD_ssp245_2021-2040
# ✅ Created SLD for MAM-CSD_ssp245 → Reds
# style MAM-CSD_ssp245 not found, skipping delete
# style uploaded MAM-CSD_ssp245
# published MAM-CSD_ssp245_2021-2040 to India_states_MAM-CSD_ssp245_2021-2040
# deleted India_states_JJAS-CDD_ssp245_2021-2040
# created data_store:India_states_JJAS-CDD_ssp245_2021-2040
# ✅ Created SLD for JJAS-CDD_ssp245 → Greens
# style JJAS-CDD_ssp245 not found, skipping delete
# style uploaded JJAS-CDD_ssp245
# published JJAS-CDD_ssp245_2021-2040 to India_states_JJAS-CDD_ssp245_2021-2040
# deleted India_states_CDD_ssp245_2021-2040
# created data_store:India_states_CDD_ssp245_2021-2040
# ✅ Created SLD for CDD_ssp245 → Reds
# style CDD_ssp245 not found, skipping delete
# style uploaded CDD_ssp245
# published CDD_ssp245_2021-2040 to India_states_CDD_ssp245_2021-2040
# deleted India_states_DJF-Tmin_ssp245_2021-2040
# created data_store:India_states_DJF-Tmin_ssp245_2021-2040
# ✅ Created SLD for DJF-Tmin_ssp245 → Reds
# style DJF-Tmin_ssp245 not found, skipping delete
# style uploaded DJF-Tmin_ssp245
# published DJF-Tmin_ssp245_2021-2040 to India_states_DJF-Tmin_ssp245_2021-2040
# deleted India_states_JJAS-Heavy-rainfall-days-10mm_ssp585_2021-2040
# created data_store:India_states_JJAS-Heavy-rainfall-days-10mm_ssp585_2021-2040
# ✅ Created SLD for JJAS-Heavy-rainfall-days-10mm_ssp585 → Greens
# style JJAS-Heavy-rainfall-days-10mm_ssp585 not found, skipping delete
# style uploaded JJAS-Heavy-rainfall-days-10mm_ssp585
# published JJAS-Heavy-rainfall-days-10mm_ssp585_2021-2040 to India_states_JJAS-Heavy-rainfall-days-10mm_ssp585_2021-2040
# deleted India_states_OND-Heavy-rainfall-days-20mm_ssp585_2021-2040
# created data_store:India_states_OND-Heavy-rainfall-days-20mm_ssp585_2021-2040
# ✅ Created SLD for OND-Heavy-rainfall-days-20mm_ssp585 → Greens
# style OND-Heavy-rainfall-days-20mm_ssp585 not found, skipping delete
# style uploaded OND-Heavy-rainfall-days-20mm_ssp585
# published OND-Heavy-rainfall-days-20mm_ssp585_2021-2040 to India_states_OND-Heavy-rainfall-days-20mm_ssp585_2021-2040
# deleted India_states_max-1day-precip_ssp585_2021-2040
# created data_store:India_states_max-1day-precip_ssp585_2021-2040
# ✅ Created SLD for max-1day-precip_ssp585 → Reds
# style max-1day-precip_ssp585 not found, skipping delete
# style uploaded max-1day-precip_ssp585
# published max-1day-precip_ssp585_2021-2040 to India_states_max-1day-precip_ssp585_2021-2040
# deleted India_states_JJAS-max-5day-precip_ssp245_2021-2040
# created data_store:India_states_JJAS-max-5day-precip_ssp245_2021-2040
# ✅ Created SLD for JJAS-max-5day-precip_ssp245 → Greens
# style JJAS-max-5day-precip_ssp245 not found, skipping delete
# style uploaded JJAS-max-5day-precip_ssp245
# published JJAS-max-5day-precip_ssp245_2021-2040 to India_states_JJAS-max-5day-precip_ssp245_2021-2040
# deleted India_states_rainyday-frequency_ssp585_2021-2040
# created data_store:India_states_rainyday-frequency_ssp585_2021-2040
# ✅ Created SLD for rainyday-frequency_ssp585 → Greens
# style rainyday-frequency_ssp585 not found, skipping delete
# style uploaded rainyday-frequency_ssp585
# published rainyday-frequency_ssp585_2021-2040 to India_states_rainyday-frequency_ssp585_2021-2040
# deleted India_states_tasmax-celsius_ssp585_2021-2040
# created data_store:India_states_tasmax-celsius_ssp585_2021-2040
# ✅ Created SLD for tasmax-celsius_ssp585 → Reds
# style tasmax-celsius_ssp585 not found, skipping delete
# style uploaded tasmax-celsius_ssp585
# published tasmax-celsius_ssp585_2021-2040 to India_states_tasmax-celsius_ssp585_2021-2040
# deleted India_states_tw_ssp585_2021-2040
# created data_store:India_states_tw_ssp585_2021-2040
# ✅ Created SLD for tw_ssp585 → Reds
# deleted tw_ssp585
# style uploaded tw_ssp585
# published tw_ssp585_2021-2040 to India_states_tw_ssp585_2021-2040
# deleted India_states_OND-SDII_ssp245_2021-2040
# created data_store:India_states_OND-SDII_ssp245_2021-2040
# ✅ Created SLD for OND-SDII_ssp245 → Greens
# style OND-SDII_ssp245 not found, skipping delete
# style uploaded OND-SDII_ssp245
# published OND-SDII_ssp245_2021-2040 to India_states_OND-SDII_ssp245_2021-2040
# deleted India_states_JJAS-CDD_ssp585_2021-2040
# created data_store:India_states_JJAS-CDD_ssp585_2021-2040
# ✅ Created SLD for JJAS-CDD_ssp585 → Greens
# style JJAS-CDD_ssp585 not found, skipping delete
# style uploaded JJAS-CDD_ssp585
# published JJAS-CDD_ssp585_2021-2040 to India_states_JJAS-CDD_ssp585_2021-2040
# deleted India_states_OND-SDII_ssp585_2021-2040
# created data_store:India_states_OND-SDII_ssp585_2021-2040
# ✅ Created SLD for OND-SDII_ssp585 → Greens
# style OND-SDII_ssp585 not found, skipping delete
# style uploaded OND-SDII_ssp585
# published OND-SDII_ssp585_2021-2040 to India_states_OND-SDII_ssp585_2021-2040
# deleted India_states_hurs_ssp245_2021-2040
# created data_store:India_states_hurs_ssp245_2021-2040
# ✅ Created SLD for hurs_ssp245 → Reds
# style hurs_ssp245 not found, skipping delete
# style uploaded hurs_ssp245
# published hurs_ssp245_2021-2040 to India_states_hurs_ssp245_2021-2040
# deleted India_states_OND-max-5day-precip_ssp245_2021-2040
# created data_store:India_states_OND-max-5day-precip_ssp245_2021-2040
# ✅ Created SLD for OND-max-5day-precip_ssp245 → Greens
# style OND-max-5day-precip_ssp245 not found, skipping delete
# style uploaded OND-max-5day-precip_ssp245
# published OND-max-5day-precip_ssp245_2021-2040 to India_states_OND-max-5day-precip_ssp245_2021-2040
# deleted India_states_pr-mm_ssp585_2021-2040
# created data_store:India_states_pr-mm_ssp585_2021-2040
# ✅ Created SLD for pr-mm_ssp585 → Greens
# style pr-mm_ssp585 not found, skipping delete
# style uploaded pr-mm_ssp585
# published pr-mm_ssp585_2021-2040 to India_states_pr-mm_ssp585_2021-2040
# deleted India_states_JJAS-SDII_ssp585_2021-2040
# created data_store:India_states_JJAS-SDII_ssp585_2021-2040
# ✅ Created SLD for JJAS-SDII_ssp585 → Greens
# style JJAS-SDII_ssp585 not found, skipping delete
# style uploaded JJAS-SDII_ssp585
# published JJAS-SDII_ssp585_2021-2040 to India_states_JJAS-SDII_ssp585_2021-2040
# deleted India_states_JJAS-Heavy-rainfall-days-20mm_ssp245_2021-2040
# created data_store:India_states_JJAS-Heavy-rainfall-days-20mm_ssp245_2021-2040
# ✅ Created SLD for JJAS-Heavy-rainfall-days-20mm_ssp245 → Greens
# style JJAS-Heavy-rainfall-days-20mm_ssp245 not found, skipping delete
# style uploaded JJAS-Heavy-rainfall-days-20mm_ssp245
# published JJAS-Heavy-rainfall-days-20mm_ssp245_2021-2040 to India_states_JJAS-Heavy-rainfall-days-20mm_ssp245_2021-2040
# deleted India_states_pr-mm-ond_ssp245_2021-2040
# created data_store:India_states_pr-mm-ond_ssp245_2021-2040
# ✅ Created SLD for pr-mm-ond_ssp245 → Greens
# style pr-mm-ond_ssp245 not found, skipping delete
# style uploaded pr-mm-ond_ssp245
# published pr-mm-ond_ssp245_2021-2040 to India_states_pr-mm-ond_ssp245_2021-2040
# deleted India_states_JJAS-max-1day-precip_ssp585_2021-2040
# created data_store:India_states_JJAS-max-1day-precip_ssp585_2021-2040
# ✅ Created SLD for JJAS-max-1day-precip_ssp585 → Greens
# style JJAS-max-1day-precip_ssp585 not found, skipping delete
# style uploaded JJAS-max-1day-precip_ssp585
# published JJAS-max-1day-precip_ssp585_2021-2040 to India_states_JJAS-max-1day-precip_ssp585_2021-2040
# deleted India_states_tasmax-celsius_ssp245_2021-2040
# created data_store:India_states_tasmax-celsius_ssp245_2021-2040
# ✅ Created SLD for tasmax-celsius_ssp245 → Reds
# style tasmax-celsius_ssp245 not found, skipping delete
# style uploaded tasmax-celsius_ssp245
# published tasmax-celsius_ssp245_2021-2040 to India_states_tasmax-celsius_ssp245_2021-2040
# deleted India_states_JJAS-Heavy-rainfall-days-20mm_ssp585_2021-2040
# created data_store:India_states_JJAS-Heavy-rainfall-days-20mm_ssp585_2021-2040
# ✅ Created SLD for JJAS-Heavy-rainfall-days-20mm_ssp585 → Greens
# style JJAS-Heavy-rainfall-days-20mm_ssp585 not found, skipping delete
# style uploaded JJAS-Heavy-rainfall-days-20mm_ssp585
# published JJAS-Heavy-rainfall-days-20mm_ssp585_2021-2040 to India_states_JJAS-Heavy-rainfall-days-20mm_ssp585_2021-2040
# deleted India_states_tasmin-celsius_ssp245_2021-2040
# created data_store:India_states_tasmin-celsius_ssp245_2021-2040
# ✅ Created SLD for tasmin-celsius_ssp245 → Reds
# style tasmin-celsius_ssp245 not found, skipping delete
# style uploaded tasmin-celsius_ssp245
# published tasmin-celsius_ssp245_2021-2040 to India_states_tasmin-celsius_ssp245_2021-2040
# deleted India_states_tw-year-max_ssp245_2021-2040
# created data_store:India_states_tw-year-max_ssp245_2021-2040
# ✅ Created SLD for tw-year-max_ssp245 → Reds
# deleted tw-year-max_ssp245
# style uploaded tw-year-max_ssp245
# published tw-year-max_ssp245_2021-2040 to India_states_tw-year-max_ssp245_2021-2040
# deleted India_states_warm-spell-duration-index_ssp585_2021-2040
# created data_store:India_states_warm-spell-duration-index_ssp585_2021-2040
# ✅ Created SLD for warm-spell-duration-index_ssp585 → Reds
# deleted warm-spell-duration-index_ssp585
# style uploaded warm-spell-duration-index_ssp585
# published warm-spell-duration-index_ssp585_2021-2040 to India_states_warm-spell-duration-index_ssp585_2021-2040
# deleted India_states_JJAS-SDII_ssp245_2021-2040
# created data_store:India_states_JJAS-SDII_ssp245_2021-2040
# ✅ Created SLD for JJAS-SDII_ssp245 → Greens
# style JJAS-SDII_ssp245 not found, skipping delete
# style uploaded JJAS-SDII_ssp245
# published JJAS-SDII_ssp245_2021-2040 to India_states_JJAS-SDII_ssp245_2021-2040
# deleted India_states_tw-MAM-max_ssp585_2021-2040
# created data_store:India_states_tw-MAM-max_ssp585_2021-2040
# ✅ Created SLD for tw-MAM-max_ssp585 → Reds
# style tw-MAM-max_ssp585 not found, skipping delete
# style uploaded tw-MAM-max_ssp585
# published tw-MAM-max_ssp585_2021-2040 to India_states_tw-MAM-max_ssp585_2021-2040
# deleted India_states_MAM-tw_ssp245_2021-2040
# created data_store:India_states_MAM-tw_ssp245_2021-2040
# ✅ Created SLD for MAM-tw_ssp245 → Reds
# style MAM-tw_ssp245 not found, skipping delete
# style uploaded MAM-tw_ssp245
# published MAM-tw_ssp245_2021-2040 to India_states_MAM-tw_ssp245_2021-2040
# deleted India_states_max-1day-precip_ssp245_2021-2040
# created data_store:India_states_max-1day-precip_ssp245_2021-2040
# ✅ Created SLD for max-1day-precip_ssp245 → Reds
# style max-1day-precip_ssp245 not found, skipping delete
# style uploaded max-1day-precip_ssp245
# published max-1day-precip_ssp245_2021-2040 to India_states_max-1day-precip_ssp245_2021-2040
# deleted India_states_CSD_ssp585_2021-2040
# created data_store:India_states_CSD_ssp585_2021-2040
# ✅ Created SLD for CSD_ssp585 → Reds
# style CSD_ssp585 not found, skipping delete
# style uploaded CSD_ssp585
# published CSD_ssp585_2021-2040 to India_states_CSD_ssp585_2021-2040
# deleted India_states_OND-CDD_ssp585_2021-2040
# created data_store:India_states_OND-CDD_ssp585_2021-2040
# ✅ Created SLD for OND-CDD_ssp585 → Greens
# style OND-CDD_ssp585 not found, skipping delete
# style uploaded OND-CDD_ssp585
# published OND-CDD_ssp585_2021-2040 to India_states_OND-CDD_ssp585_2021-2040
# deleted India_states_warm-spell-duration-index_ssp245_2021-2040
# created data_store:India_states_warm-spell-duration-index_ssp245_2021-2040
# ✅ Created SLD for warm-spell-duration-index_ssp245 → Reds
# deleted warm-spell-duration-index_ssp245
# style uploaded warm-spell-duration-index_ssp245
# published warm-spell-duration-index_ssp245_2021-2040 to India_states_warm-spell-duration-index_ssp245_2021-2040
# deleted India_states_OND-Heavy-rainfall-days-10mm_ssp585_2021-2040
# created data_store:India_states_OND-Heavy-rainfall-days-10mm_ssp585_2021-2040
# ✅ Created SLD for OND-Heavy-rainfall-days-10mm_ssp585 → Greens
# style OND-Heavy-rainfall-days-10mm_ssp585 not found, skipping delete
# style uploaded OND-Heavy-rainfall-days-10mm_ssp585
# published OND-Heavy-rainfall-days-10mm_ssp585_2021-2040 to India_states_OND-Heavy-rainfall-days-10mm_ssp585_2021-2040
# deleted India_states_OND-max-1day-precip_ssp245_2021-2040
# created data_store:India_states_OND-max-1day-precip_ssp245_2021-2040
# ✅ Created SLD for OND-max-1day-precip_ssp245 → Greens
# style OND-max-1day-precip_ssp245 not found, skipping delete
# style uploaded OND-max-1day-precip_ssp245
# published OND-max-1day-precip_ssp245_2021-2040 to India_states_OND-max-1day-precip_ssp245_2021-2040
# deleted India_states_pr-mm-jjas_ssp245_2021-2040
# created data_store:India_states_pr-mm-jjas_ssp245_2021-2040
# ✅ Created SLD for pr-mm-jjas_ssp245 → Greens
# style pr-mm-jjas_ssp245 not found, skipping delete
# style uploaded pr-mm-jjas_ssp245
# published pr-mm-jjas_ssp245_2021-2040 to India_states_pr-mm-jjas_ssp245_2021-2040
# deleted India_states_JJAS-max-1day-precip_ssp245_2021-2040
# created data_store:India_states_JJAS-max-1day-precip_ssp245_2021-2040
# ✅ Created SLD for JJAS-max-1day-precip_ssp245 → Greens
# style JJAS-max-1day-precip_ssp245 not found, skipping delete
# style uploaded JJAS-max-1day-precip_ssp245
# published JJAS-max-1day-precip_ssp245_2021-2040 to India_states_JJAS-max-1day-precip_ssp245_2021-2040
# deleted India_states_tasmin-celsius_ssp585_2021-2040
# created data_store:India_states_tasmin-celsius_ssp585_2021-2040
# ✅ Created SLD for tasmin-celsius_ssp585 → Reds
# style tasmin-celsius_ssp585 not found, skipping delete
# style uploaded tasmin-celsius_ssp585
# published tasmin-celsius_ssp585_2021-2040 to India_states_tasmin-celsius_ssp585_2021-2040
# deleted India_states_tas-celsius_ssp585_2021-2040
# created data_store:India_states_tas-celsius_ssp585_2021-2040
# ✅ Created SLD for tas-celsius_ssp585 → Reds
# style tas-celsius_ssp585 not found, skipping delete
# style uploaded tas-celsius_ssp585
# published tas-celsius_ssp585_2021-2040 to India_states_tas-celsius_ssp585_2021-2040
# deleted India_states_OND-Heavy-rainfall-days-20mm_ssp245_2021-2040
# created data_store:India_states_OND-Heavy-rainfall-days-20mm_ssp245_2021-2040
# ✅ Created SLD for OND-Heavy-rainfall-days-20mm_ssp245 → Greens
# style OND-Heavy-rainfall-days-20mm_ssp245 not found, skipping delete
# style uploaded OND-Heavy-rainfall-days-20mm_ssp245
# published OND-Heavy-rainfall-days-20mm_ssp245_2021-2040 to India_states_OND-Heavy-rainfall-days-20mm_ssp245_2021-2040
# deleted India_states_DJF-Tmin_ssp585_2021-2040
# created data_store:India_states_DJF-Tmin_ssp585_2021-2040
# ✅ Created SLD for DJF-Tmin_ssp585 → Reds
# style DJF-Tmin_ssp585 not found, skipping delete
# style uploaded DJF-Tmin_ssp585
# published DJF-Tmin_ssp585_2021-2040 to India_states_DJF-Tmin_ssp585_2021-2040
# deleted India_states_pr-mm_ssp245_2021-2040
# created data_store:India_states_pr-mm_ssp245_2021-2040
# ✅ Created SLD for pr-mm_ssp245 → Greens
# style pr-mm_ssp245 not found, skipping delete
# style uploaded pr-mm_ssp245
# published pr-mm_ssp245_2021-2040 to India_states_pr-mm_ssp245_2021-2040
# deleted India_states_JJAS-max-5day-precip_ssp585_2021-2040
# created data_store:India_states_JJAS-max-5day-precip_ssp585_2021-2040
# ✅ Created SLD for JJAS-max-5day-precip_ssp585 → Greens
# style JJAS-max-5day-precip_ssp585 not found, skipping delete
# style uploaded JJAS-max-5day-precip_ssp585
# published JJAS-max-5day-precip_ssp585_2021-2040 to India_states_JJAS-max-5day-precip_ssp585_2021-2040
# deleted India_states_pr-mm-jjas_ssp585_2021-2040
# created data_store:India_states_pr-mm-jjas_ssp585_2021-2040
# ✅ Created SLD for pr-mm-jjas_ssp585 → Greens
# style pr-mm-jjas_ssp585 not found, skipping delete
# style uploaded pr-mm-jjas_ssp585
# published pr-mm-jjas_ssp585_2021-2040 to India_states_pr-mm-jjas_ssp585_2021-2040
# deleted India_states_MAM-tmax_ssp585_2021-2040
# created data_store:India_states_MAM-tmax_ssp585_2021-2040
# ✅ Created SLD for MAM-tmax_ssp585 → Reds
# style MAM-tmax_ssp585 not found, skipping delete
# style uploaded MAM-tmax_ssp585
# published MAM-tmax_ssp585_2021-2040 to India_states_MAM-tmax_ssp585_2021-2040
# deleted India_states_MAM-tmax_ssp245_2021-2040
# created data_store:India_states_MAM-tmax_ssp245_2021-2040
# ✅ Created SLD for MAM-tmax_ssp245 → Reds
# style MAM-tmax_ssp245 not found, skipping delete
# style uploaded MAM-tmax_ssp245
# published MAM-tmax_ssp245_2021-2040 to India_states_MAM-tmax_ssp245_2021-2040
# deleted India_states_MAM-rh_ssp245_2021-2040
# created data_store:India_states_MAM-rh_ssp245_2021-2040
# ✅ Created SLD for MAM-rh_ssp245 → Reds
# style MAM-rh_ssp245 not found, skipping delete
# style uploaded MAM-rh_ssp245
# published MAM-rh_ssp245_2021-2040 to India_states_MAM-rh_ssp245_2021-2040
